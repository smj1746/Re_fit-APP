# %% [markdown]
# # Re_fit 커스텀 포즈 분류 모델 학습
#
# 이 노트북은 Re_fit 안드로이드 앱을 위한 온디바이스 포즈 분류 모델을 학습합니다.
#
# ## 주요 기능
# - MoveNet 기반 17개 키포인트 추출
# - BiLSTM 시퀀스 분류 모델
# - 실시간 운동 감지 (스쿼트, 푸시업, 플랭크)
# - TFLite 모델 최적화

# %% [markdown]
# ## 1. 환경 설정 및 패키지 설치

# %%
# 필요한 패키지 설치
# %pip install -q tensorflow tensorflow_hub tensorflow-model-optimization tensorflow-addons
# %pip install -q opencv-python matplotlib seaborn scikit-learn
# %pip install -q tqdm
